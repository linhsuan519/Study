# %% [markdown]
# <a href="https://colab.research.google.com/github/linhsuan519/hello-colab/blob/main/Task_05_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #利用視覺化觀察資料

# %% [markdown]
# 練習：請根據提供的 `iris` 資料，完成以下操作：
#
# 1. 利用資料視覺化觀察 sepal 和 petal 四個欄位的關係。
# 2. 利用相關係數觀察 sepal 和 petal 四個欄位的關係。

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import seaborn as sns

iris = load_iris()
df = pd.DataFrame(data = np.c_[iris['data'], iris['target']],
                     columns = iris['feature_names'] + ['target'])

# 繪製線圖
sns.lineplot(data=df[['sepal length (cm)', 'sepal width (cm)', \
                      'petal length (cm)', 'petal width (cm)']])
plt.show()

# 計算相關係數
correlation_matrix = df[['sepal length (cm)', 'sepal width (cm)', \
                         'petal length (cm)', 'petal width (cm)','target']].corr()
display(correlation_matrix)
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# target                      0.782561         -0.426658           0.949035
#
#                    petal width (cm)    target
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# target                     0.956547  1.000000

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
import seaborn as sns
iris = load_iris()
df = pd.DataFrame(data= np.c_[iris['data'], iris['target']],
                     columns= iris['feature_names'] + ['target'])
selected_features = ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

#利用資料視覺化觀察 sepal 和 petal 四個欄位的關係
sns.lineplot(data=df[selected_features])
plt.xlabel('measurement')
plt.ylabel('value')
plt.show()

# sepal 和 petal 四個欄位的關係
correlation_matrix = df[selected_features+['target']].corr()
sns.heatmap(correlation_matrix, annot= True, cmap='coolwarm', linewidths=0.5)
plt.show()

# %%
fig, ax = plt.subplots(2,2)

sns.scatterplot(ax = ax[0,0], x = df.iloc[:,0], y = df.iloc[:,1])
sns.scatterplot(ax = ax[0,1], x = df.iloc[:,2], y = df.iloc[:,3], c = "c")
sns.lineplot(ax = ax[1,0], data = df.iloc[:,0], label = "sepal_length")
sns.lineplot(ax = ax[1,0], data = df.iloc[:,1], label = "sepal_width")
sns.lineplot(ax = ax[1,1], data = df.iloc[:,2], label = "petal_length", c = "c")
sns.lineplot(ax = ax[1,1], data = df.iloc[:,3], label = "petal_width", c = "r")

# 相關係數
print(df.corr())
fig2, ax2 = plt.subplots()
sns.heatmap(data = df.corr(), annot = True)
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
# target                      0.782561         -0.426658           0.949035
#
#                    petal width (cm)    target
# sepal length (cm)          0.817941  0.782561
# sepal width (cm)          -0.366126 -0.426658
# petal length (cm)          0.962865  0.949035
# petal width (cm)           1.000000  0.956547
# target                     0.956547  1.000000
# <Axes: >
